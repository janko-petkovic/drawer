# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-l73tdacy because the default path (/home/janko/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
def A(x, sigma,rho,beta):
    # print(x)
    dxdt = sigma * (x[1] - x[0])
    dydt = rho*x[0] - x[0]*x[2] - x[1]
    dzdt = x[0]*x[1] - beta*x[2]

    # dxdt = x[1]
    # dydt = -x[0]

    return np.array([dxdt, dydt, dzdt])

x = [np.array([1,2,3])]

p = [10,20,8/3]

dt = 1e-2
epochs = 9000

for _ in range(epochs):
    dx = A(x[-1], *p) * dt
    x.append(x[-1] + dx)

x = np.stack(x, axis=0)

sequence = x[:,0]


fig = plt.figure(figsize=(5,7))
gs = fig.add_gridspec(ncols=1, nrows=2, height_ratios=(5,1))

ax = fig.add_subplot(gs[0], projection='3d')
ax.scatter(x[:,0], x[:,1], x[:,2], alpha=0.2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax = fig.add_subplot(gs[1])
ax.plot(np.arange(epochs+1), x[:,0])
ax.set_xlabel('Time')
ax.set_ylabel('x')

plt.subplots_adjust(right=1.1)

# %% [markdown]
# # Deep approaches

# %%
# from scipy.signal import correlate, correlation_lags


# fig, axs = plt.subplots(1,3,figsize=(10,3))
# fig.subplots_adjust(wspace=0.5, hspace=0.5)

# for ax, dim in zip(axs, [0,1]):

#     X = x[:len(x[:,dim])//2,dim]
#     Y = x[:,dim]

#     X = (X - Y.mean())/Y.std()
#     Y = (Y - Y.mean())/Y.std()


#     corr = correlate(X,Y, mode='valid')/len(Y)
#     lags = correlation_lags(len(X),len(Y), mode='valid')


#     ax.plot(lags, corr)
#     ax.set_title(f'Spectrum dim {dim}')
#     ax.set_xlabel(r"Lag")

#     ax.set_ylabel(r"Linear corr coeff")

#     # ax.set_ylim(-0.02, 0.02)
#     # ax.set_yscale('log')
#     ax.ticklabel_format(axis='x', scilimits=[0,1])


# xx = np.random.poisson(10, 9000)
# X = xx[:len(xx)//2]
# Y = xx

# X = (X - Y.mean())/Y.std()
# Y = (Y - Y.mean())/Y.std()

# corr = correlate(X,Y, mode='valid')/len(Y)
# lags = correlation_lags(len(X),len(Y), mode='valid')

# ax = axs[-1]
# ax.plot(lags, corr)
# ax.set_title(f'Spectrum random distr')
# ax.set_xlabel(r"Lag")

# ax.set_ylabel(r"Linear corr coeff")

# ax.set_ylim(-0.02, 0.02)
# ax.ticklabel_format(axis='x', scilimits=[0,1])

# %%
# def f(x, n):
#     return np.sum([(-x)**i for i in range(n)], axis=0)

# x = np.linspace(0,2,100)

# plt.plot(x, f(x,20))

# %%
# import torch

# class PappoSet(torch.utils.data.Dataset): 
#     def __init__(self, X, Y, L):
#         self.X = torch.Tensor(X)  
#         self.Y = torch.Tensor(Y)
#         self.L = L

#     def __len__(self):
#         return self.Y.shape[0] - L
    
#     def __getitem__(self, i):
#         return self.X[i:i+L], self.Y[i+L] # Return the i-th sample

#     def labels(self):
#         return self.Y.detach().numpy()

# %%
# L = 50

# split_idx = int(len(X)*0.8)
# trainset = PappoSet(X[:split_idx],Y[:split_idx],L)
# validset = PappoSet(X[split_idx:],Y[split_idx:],L)

# %%
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=2)
# validloader = torch.utils.data.DataLoader(validset, batch_size=64)

# %%
# class PappoNN(torch.nn.Module):
#     def __init__(self, input_size, hidden_size, output_size):
#         super().__init__()

#         self.linear = torch.nn.Linear(input_size, hidden_size)
#         self.relu = torch.nn.ReLU()
#         self.readout = torch.nn.Linear(hidden_size, output_size)
    
#     def forward(self, x):
#         x = self.relu(self.linear(x))
#         return self.readout(x)


# class PappoCNN(torch.nn.Module):
#     def __init__(self, ks1, ks2, output_size):
#         super().__init__()

#         self.c1 = torch.nn.Conv1d(1,1,ks1, padding=1)
#         self.c2 = torch.nn.Conv1d(1,1,ks2, padding=3)
#         self.relu = torch.nn.ReLU()
#         self.readout = torch.nn.Linear(10, output_size)
    
#     def forward(self, x):
#         x = x.unsqueeze(dim=1)
#         x = self.relu(self.c1(x))
#         x = self.relu(self.c2(x))
#         return self.readout(x)

# %%
# model = PappoNN(L, 50, 1)
# # model = PappoCNN(3, 7, 1)

# opt = torch.optim.Adam(model.parameters(), lr=1e-3)
# loss_fn = torch.nn.MSELoss()

# %%
# epochs = 20

# trainlosses = np.zeros(epochs)
# validlosses = np.zeros(epochs)

# for _ in tqdm(range(epochs), desc="Training Network...", unit="epoch"):
#     model.train()

#     for X, Y in trainloader:
#         Y_pred = model(X)
#         loss = loss_fn(Y, Y_pred)
        
#         opt.zero_grad()
#         loss.backward()
#         opt.step()

#         trainloss = 0
#         trainlosses[_] += loss.detach().numpy()/len(trainset)

#     model.eval()
#     for X, Y in validloader:
#         Y_pred = model(X)
#         loss = loss_fn(Y, Y_pred)

#         validlosses[_] += loss.detach().numpy()/len(validset)


# plt.plot(trainlosses, '-x', c='tab:blue')
# plt.plot(validlosses, '-x', c='tab:red')

# %%
# train_prediction = []
# valid_prediction = []

# for X, Y in trainloader:
#     Y_pred = model(X)
#     train_prediction.append(Y_pred.detach().numpy())

# for X, Y in validloader:
#     Y_pred = model(X)
#     valid_prediction.append(Y_pred.detach().numpy())


# train_prediction = np.concatenate(train_prediction).squeeze()
# valid_prediction = np.concatenate(valid_prediction).squeeze()

# fig, axs = plt.subplots(1,2, figsize=(10,2), sharey=True, width_ratios=(5,1))

# ax = axs[0]
# ax.plot(trainset.labels(), c='gray', linewidth=2, label='Data')
# ax.plot(np.arange(len(train_prediction))+9, train_prediction, c='tab:red', linewidth=2, label='Prediction')
# ax.legend(frameon=False, ncols=2)

# ax.set_title('Training')
# ax.set_xlabel('Time')
# ax.set_ylabel('Coordinate x')

# ax = axs[1]
# ax.plot(validset.labels(), c='gray', linewidth=2)
# ax.plot(np.arange(len(valid_prediction))+9, valid_prediction, c='tab:red', linewidth=2)

# ax.set_title('Validation')
# ax.set_xlabel('Time')

# plt.subplots_adjust(wspace=0.1)

# %% [markdown]
# # Reservoir approach

# %%
class Reservoir:
    '''
    x_t = h(W x_t-1 + Q z_t + R)
    y_t = Ax_t + B
    '''
    def __init__(self, state_dim, input_dim):
        self.W = np.random.randn(state_dim, state_dim)/np.sqrt(state_dim)*0.9
        self.Q = np.random.randn(state_dim, input_dim)/np.sqrt(state_dim)*0.8
        self.R = np.random.randn(state_dim, 1)
        self.A = np.random.randn(input_dim, state_dim)
        self.B = np.random.randn(input_dim, 1)

        self.x = np.random.randn(state_dim, 1)


    def _nonlin(self, x):
        return np.arctan(x)
        # return np.where(x>0, x, 0)

    def step(self, z):
        self.x = self._nonlin(
            self.W @ self.x + self.Q * z# + self.R
        )

    def read(self):
        return self.A @ self.x + self.B


# Define reservoir
reservoir = Reservoir(100, 1)
driving_idx = 8000


states = []
outs = np.empty_like(sequence[:driving_idx])

for idx, z in enumerate(sequence[:driving_idx]):
    reservoir.step(z)
    outs[idx] = reservoir.read()
    states.append(reservoir.x)

states = np.stack(states, axis=0).squeeze()
states = states[500:]
sequence = sequence[500:]
driving_idx = driving_idx - 500

# %%
fig = plt.figure(figsize=(15,5))
gs = fig.add_gridspec(ncols=2, nrows=4, width_ratios=(1,2))

ax = fig.add_subplot(gs[:,0], projection='3d')
ax.scatter(states.T[0], states.T[1], states.T[2], alpha=0.2, c='Forestgreen', s=2)

ax.set_title('Reservoir configuration space')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

for i, lab in enumerate(['x','y','z']):
    ax = fig.add_subplot(gs[i,1])
    ax.scatter(np.arange(driving_idx), states.T[i], s=1, c='Forestgreen')
    ax.set_xticklabels('')
    ax.set_ylabel(lab)

ax = fig.add_subplot(gs[3,1])
ax.scatter(np.arange(driving_idx), sequence[:driving_idx], s=1, c='gray')
ax.set_xlabel('Time')
ax.set_ylabel('driver')

plt.subplots_adjust(hspace=0.4, wspace=0.3)

# %% [markdown]
# ### Check the readout accuracy on the training

# %%
W =  np.linalg.pinv(states) @ sequence[:driving_idx]

prediction = states @ W

fig, ax = plt.subplots(1,1, figsize=(8,2))
ax.plot(sequence[:driving_idx])
ax.plot(prediction, linestyle='--')

se = (prediction - sequence[:driving_idx])**2
se.mean()/sequence[:driving_idx].var()
# Out:
# 8.615580629352053e-13

# %%
U, Sigma, Vh = np.linalg.svd(states, full_matrices=False)

# %%
fig = plt.figure(figsize=(15,5))
gs = fig.add_gridspec(ncols=2, nrows=4, width_ratios=(1,2))

ax = fig.add_subplot(gs[:,0], projection='3d')
ax.scatter(U.T[0], U.T[1], U.T[2], alpha=0.2, c='Forestgreen', s=2)

ax.set_title('Reservoir configuration space')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

for i, lab in enumerate(['x','y','z']):
    ax = fig.add_subplot(gs[i,1])
    ax.scatter(np.arange(driving_idx), U.T[i], s=1, c='Forestgreen')
    ax.set_xticklabels('')
    ax.set_ylabel(lab)

ax = fig.add_subplot(gs[3,1])
ax.scatter(np.arange(driving_idx), sequence[:driving_idx], s=1, c='gray')
ax.set_xlabel('Time')
ax.set_ylabel('driver')

plt.subplots_adjust(hspace=0.4, wspace=0.3)

# %%
from xicorpy import compute_xi_correlation as cxc
from pprint import pprint

def xi_matrix(data):

    xi_matrix = np.eye((len(data)))

    for i, d1 in enumerate(data[:-1]):

        for j, d2 in enumerate(data[i+1:]):

            ij = cxc(d1, d2).item()
            ji = cxc(d2, d1).item()

            xi_matrix[i,i+j+1] = xi_matrix[i+j+1,i] = max(ij, ji)

    return xi_matrix



M = xi_matrix(states.T)
# Diagonalize covariance
eigval, eigvec = np.linalg.eigh(M)

# %%
plt.bar(range(len(Sigma)), Sigma**2)
plt.gca().set_yscale('log')

# %%
new_data = eigvec.T @ states.T


fig, axs = plt.subplots(1,2, figsize=(6,3))

ax = axs[0]
ax.bar(range(len(eigval)), eigval[::-1])
ax.set_yscale('log')

ax = axs[1]
ax.scatter(new_data[-1], sequence[:driving_idx])

# %%
fig = plt.figure(figsize=(15,5))
gs = fig.add_gridspec(ncols=2, nrows=4, width_ratios=(1,2))

ax = fig.add_subplot(gs[:,0], projection='3d')
ax.scatter(new_data[-1], new_data[-2], new_data[-3], alpha=0.2, c='Forestgreen', s=2)

ax.set_title('Reservoir configuration space')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

for i, lab in enumerate(['x','y','z']):
    ax = fig.add_subplot(gs[i,1])
    ax.scatter(np.arange(driving_idx), new_data[-i], s=1, c='Forestgreen')
    ax.set_xticklabels('')
    ax.set_ylabel(lab)

ax = fig.add_subplot(gs[3,1])
ax.scatter(np.arange(driving_idx), sequence[:driving_idx], s=1, c='gray')
ax.set_xlabel('Time')
ax.set_ylabel('driver')

plt.subplots_adjust(hspace=0.4, wspace=0.3)

# %% [markdown]
# Foci method

# %%
import xicorpy

Y = sequence[:driving_idx]
idxes = xicorpy.select_features_using_foci(Y, states, num_features=10)
print(idxes)
# Out:
# [50, 67, 83, 18, 53, 23, 64]

# %%
fig, axs = plt.subplots(len(idxes)+1,2, width_ratios=(7,1), dpi=150)
axs[-1,1].remove()

for idx, row in zip(idxes, axs):
    ax = row[0]
    # idx=1
    ax.plot(states[:,idx])
    ax.set_ylabel(f'Neuron {idx}', rotation=0, va='center', ha='right')
    ax.set_ylim(-2,2)
    ax.set_xticklabels([])

    ax = row[1]
    ax.scatter(Y, states[:,idx], s=0.1)
    ax.set_xlim(-20,20)
    ax.set_ylim(-2,2)
    ax.set_yticks([])
    ax.set_xticks([])
    ax.set_xlabel('Driver')
    ax.yaxis.set_label_position('right')
    ax.set_ylabel(f'Neuron {idx}', rotation=0, ha='left', va='center')

ax = axs[-1,0]
ax.plot(Y, color='tab:red')

ax.set_ylim(-20,20)
ax.set_xlabel('Time')
ax.set_ylabel(f'Driver', rotation=0, va='center', ha='right')

fig.subplots_adjust(hspace=0.5, wspace=0.1)
