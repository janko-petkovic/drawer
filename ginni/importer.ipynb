# %%
import os
import pandas as pd

# %%
os.path.join('asoid',group,file).normpath()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/janko/code/drawer/ginni/importer.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/home/janko/code/drawer/ginni/importer.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> os.path.join('asoid',group,file).normpath()
#
# AttributeError: 'str' object has no attribute 'normpath'

# %%
for group in os.listdir('raw'):
    
    print('Group: ', group)

    for file in os.listdir('raw/'+group):
        print('File: ', file)
        
        # carica i file
        raw_path = os.path.join('raw', group, file)
        df_raw = pd.read_csv(raw_path)

        for asoid_file_name in os.listdir(f';asoid', group):
            if file in asoid_file_name:
                asoid_path = os.path.join('asoid', group, asoid_file_name)

        df_asoid = pd.read_csv(raw_path)
        ####

        # Fai cose ####


        # salva l'output
        name_of_output_file = 'output-' + file

        path_to_save = os.path.join('output', group, name_of_output_file)
        df_asoid.to_csv(path_to_save)
# Out:
# Group:  group1
# File:  tomato.csv
# File:  potato.csv
# Group:  group2
# File:  tomato.csv
# File:  potato.csv
